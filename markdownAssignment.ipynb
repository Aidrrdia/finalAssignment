# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Adrian** <br> Sales Consultant

# %% [markdown]
# *I am interested in data science because it is useful*

# %% [markdown]
# ### It executes and displays an output

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# ~This is valid~
# ***
# * Nuber one
# * Number two
# * Number three
